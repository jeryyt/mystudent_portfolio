# %%
# !pip install pygame
# Out:
# ...
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.6 MB ? eta -:--:--
# ...

# %% [markdown]
# # User
# i want you to create a game with good interface

# %% [markdown]
# # Assistant
# I'll help you create a simple game using Pygame, which is a popular Python library for game development. Here's a basic template for a simple shooting game with a good interface.
#
# First, make sure you have Pygame installed using: `pip install pygame`

# %%
import pygame
import random
import sys

# Initialize Pygame
pygame.init()

# Set up the game window
WIDTH = 800
HEIGHT = 600
window = pygame.display.set_mode((WIDTH, HEIGHT))
pygame.display.set_caption("Space Shooter")

# Colors
WHITE = (255, 255, 255)
BLACK = (0, 0, 0)
RED = (255, 0, 0)

# Player settings
player_width = 50
player_height = 50
player_x = WIDTH // 2 - player_width // 2
player_y = HEIGHT - player_height - 20
player_speed = 5

# Enemy settings
enemy_width = 40
enemy_height = 40
enemy_speed = 3
enemies = []

# Game settings
clock = pygame.time.Clock()
score = 0
font = pygame.font.Font(None, 36)

def draw_player(x, y):
    pygame.draw.rect(window, WHITE, (x, y, player_width, player_height))

def create_enemy():
    x = random.randint(0, WIDTH - enemy_width)
    return {'x': x, 'y': -enemy_height}

def draw_enemy(enemy):
    pygame.draw.rect(window, RED, (enemy['x'], enemy['y'], enemy_width, enemy_height))

def main():
    global score
    running = True
    
    while running:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                running = False
        
        # Player movement
        keys = pygame.key.get_pressed()
        if keys[pygame.K_LEFT] and player_x > 0:
            player_x -= player_speed
        if keys[pygame.K_RIGHT] and player_x < WIDTH - player_width:
            player_x += player_speed
            
        # Create new enemies
        if len(enemies) < 5 and random.random() < 0.02:
            enemies.append(create_enemy())
            
        # Update enemy positions
        for enemy in enemies[:]:
            enemy['y'] += enemy_speed
            if enemy['y'] > HEIGHT:
                enemies.remove(enemy)
                score += 1
                
        # Check collisions
        player_rect = pygame.Rect(player_x, player_y, player_width, player_height)
        for enemy in enemies[:]:
            enemy_rect = pygame.Rect(enemy['x'], enemy['y'], enemy_width, enemy_height)
            if player_rect.colliderect(enemy_rect):
                running = False
                
        # Draw everything
        window.fill(BLACK)
        draw_player(player_x, player_y)
        for enemy in enemies:
            draw_enemy(enemy)
            
        # Draw score
        score_text = font.render(f"Score: {score}", True, WHITE)
        window.blit(score_text, (10, 10))
        
        pygame.display.flip()
        clock.tick(60)

    pygame.quit()
    sys.exit()

if __name__ == "__main__":
    main()
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 98
#      95     sys.exit()
#      97 if __name__ == "__main__":
# ---> 98     main()
#
# Cell In[8], line 75, in main()
#      72         score += 1
#      74 # Check collisions
# ---> 75 player_rect = pygame.Rect(player_x, player_y, player_width, player_height)
#      76 for enemy in enemies[:]:
#      77     enemy_rect = pygame.Rect(enemy['x'], enemy['y'], enemy_width, enemy_height)
#
# UnboundLocalError: cannot access local variable 'player_x' where it is not associated with a value

# %% [markdown]
# This code creates a simple space shooter game with the following features:
# 1. Clean interface with score display
# 2. Player movement using arrow keys
# 3. Falling enemies
# 4. Collision detection
# 5. Score tracking
#
# To enhance this game further, you could consider adding:
# 1. Sound effects using pygame.mixer
# 2. Sprite images instead of rectangles
# 3. Power-ups
# 4. Multiple levels
# 5. Menu system
# 6. High score system
#
# Additional recommended packages for game development:
# 1. `pygame-gui` - For creating GUI elements
# 2. `pymunk` - For physics simulation
# 3. `numpy` - For complex calculations
# 4. `pillow` - For image processing
# 5. `pygame-menu` - For creating game menus
#
# Remember to handle the game assets (images, sounds) properly and organize your code into classes for better maintainability as your game grows in complexity.
